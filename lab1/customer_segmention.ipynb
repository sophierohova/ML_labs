# %% [markdown]
# # Набор данных о поведении клиентов
# https://www.kaggle.com/datasets/a0bfff046bf6e7722a16b78630268984b89571cabd695b8587ced3a9bb1f1d7f

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

df = pd.read_csv("customer_segmentation_mixed.csv")

df.info()
df.describe()
print()
df.dtypes

# создание пропусков
df.loc[5, 'Age'] = np.nan
df.loc[12, 'Annual_Income'] = np.nan
df.loc[20, 'Gender'] = np.nan
df.loc[33, 'Preferred_Product'] = np.nan

print(df.isnull().sum())
print()

# типы признаков
numeric_columns = df.select_dtypes(include='number').columns
categorical_columns = df.select_dtypes(exclude='number').columns

print("Numeric columns:", numeric_columns)
print("Categorical columns:", categorical_columns)
print()

age_mean = df['Age'].mean()
income_mean = df['Annual_Income'].mean()
gender_mode = df['Gender'].mode()[0]
product_mode = df['Preferred_Product'].mode()[0]

df['Age'] = df['Age'].fillna(age_mean)
df['Annual_Income'] = df['Annual_Income'].fillna(income_mean)
df['Gender'] = df['Gender'].fillna(gender_mode)
df['Preferred_Product'] = df['Preferred_Product'].fillna(product_mode)

df.isnull().sum()

# нормализация
scaler = MinMaxScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])
df[numeric_columns].describe()

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

df = pd.get_dummies( df,
    columns=['Gender', 'Preferred_Product'],
    drop_first=True
)

train_df, test_df = train_test_split( df,
    test_size=0.3,
    random_state=42
)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

print(df.head())
df.info()

df.to_csv("processed_customer_segmentation.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.preprocessing import MinMaxScaler
#       4 from sklearn.model_selection import train_test_split
#       5
#       6 df = pd.read_csv("customer_segmentation_mixed.csv")
#
# ModuleNotFoundError: No module named 'sklearn'
